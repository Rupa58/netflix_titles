# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("netflix_titles_sample.csv")

# %%
print("Original Data:")
# Out:
# Original Data:

# %%
df.shape
# Out:
# (8983, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8983 entries, 0 to 8982
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8983 non-null   object
#  1   type          8983 non-null   object
#  2   title         8983 non-null   object
#  3   director      6004 non-null   object
#  4   cast          7730 non-null   object
#  5   country       7728 non-null   object
#  6   date_added    8516 non-null   object
#  7   release_year  8983 non-null   int64
#  8   rating        8979 non-null   object
#  9   duration      8980 non-null   object
#  10  listed_in     8983 non-null   object
#  11  description   8983 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 842.3+ KB

# %%
df.describe()
# Out:
#        release_year
# count   8983.000000
# mean    2014.183569
# std        8.800571
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.head(4)
# Out:
#   show_id     type                  title         director  \
# 0      s1    movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  tv show          Blood & Water              NaN
# 2      s3  tv show              Ganglands  Julien Leclercq
# 3      s4  TV SHOW  Jailbirds New Orleans              NaN
#
#                                                 cast        country  \
# 0                                                NaN  united states
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   south africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
#
#            date_added  release_year rating   duration  \
# 0          25-09-2021          2020  pg-13     90 min
# 1  September 24, 2021          2021  tv-ma  2 Seasons
# 2          09/24/2021          2021  tv-ma   1 Season
# 3          24-09-2021          2021  tv-ma   1 Season
#
# ...

# %%
df.tail(4)
# Out:
#      show_id     type                title  \
# 8979   s2989    movie              Menashe
# 8980   s4237    MOVIE  Mexicanos de Bronce
# 8981    s578  TV SHOW      Masameer County
# 8982   s2399    movie           Okko's Inn
#
#                                     director  \
# 8979  Josh Z. Weinstein, Joshua Z. Weinstein
# 8980                                     NaN
# 8981                             Malik Nejer
# 8982                           Kitaro Kosaka
#
#                                                    cast        country  \
# 8979  Menashe Lustig, Ruben Niborski, Yoel Weisshaus...  united states
# 8980                                                NaN            NaN
# 8981  Malik Nejer, Abdulaziz Alshehri, Mazroa Almazr...            NaN
# 8982  Seiran Kobayashi, Nana Mizuki, Satsumi Matsuda...          japan
#
#          date_added  release_year rating  duration  \
# 8979     25-01-2020          2017     pg    82 min
# ...

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8983, step=1)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['country'].unique()
# Out:
# array(['united states', 'south africa', nan, 'india',
#        'united states, ghana, burkina faso, united kingdom, germany, ethiopia',
#        'united kingdom', 'germany, czech republic', 'mexico', 'australia',
#        'united states, india, france', 'finland',
#        'china, canada, united states',
#        'south africa, united states, japan', 'nigeria', 'japan',
#        'spain, united states', 'france', 'belgium',
#        'united kingdom, united states', 'united states, united kingdom',
#        'france, united states', 'south korea', 'spain',
#        'united states, singapore', 'united kingdom, australia, france',
#        'united kingdom, australia, france, united states',
#        'united states, canada', 'germany, united states',
#        'south africa, united states', 'united states, mexico',
#        'united states, italy, france, japan',
#        'united states, italy, romania, united kingdom',
#        'australia, united states', 'argentina, venezuela',
# ...

# %%
df['country'].nunique()
# Out:
# 716

# %%
df['country'].value_counts()
# Out:
# country
# united states                            2738
# india                                     938
# united kingdom                            398
# japan                                     240
# south korea                               189
#                                          ...
# united states, sweden, norway               1
# united states, greece, united kingdom       1
# united kingdom, lithuania                   1
# austria, united states                      1
# united states, india, france                1
# Name: count, Length: 716, dtype: int64

# %%
df.dropna().head(4)
# Out:
#    show_id     type                          title             director  \
# 7       s8    MOVIE                        Sankofa         Haile Gerima
# 8       s9  tv show  The Great British Baking Show      Andy Devonshire
# 9      s10    MOVIE                   The Starling       Theodore Melfi
# 12     s13    movie                   Je Suis Karl  Christian Schwochow
#
#                                                  cast  \
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8   Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
#
#                                               country          date_added  \
# 7   united states, ghana, burkina faso, united kin...  September 24, 2021
# 8                                      united kingdom          09/24/2021
# 9                                       united states  September 24, 2021
# ...

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2979
# cast            1253
# country         1255
# date_added       467
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.dropna().tail(4)
# Out:
#      show_id   type                          title  \
# 8974    s886  movie                  Table Manners
# 8975   s6993  MOVIE  Hoodwinked Too! Hood vs. Evil
# 8979   s2989  movie                        Menashe
# 8982   s2399  movie                     Okko's Inn
#
#                                     director  \
# 8974                               Leli Maki
# 8975                               Mike Disa
# 8979  Josh Z. Weinstein, Joshua Z. Weinstein
# 8982                           Kitaro Kosaka
#
#                                                    cast               country  \
# 8974  Diaan Lawrenson, Renate Stuurman, Neels Van Ja...  canada, south africa
# 8975  Hayden Panettiere, Glenn Close, Patrick Warbur...         united states
# 8979  Menashe Lustig, Ruben Niborski, Yoel Weisshaus...         united states
# 8982  Seiran Kobayashi, Nana Mizuki, Satsumi Matsuda...                 japan
#
#          date_added  release_year rating duration  \
# ...

# %%
df = df.fillna({
    'director': 'Unknown',
    'cast': 'Unknown',
    'rating': 'Not Rated',
    'country': 'Unknown'
})
df.sample()
# Out:
#      show_id     type      title director     cast  country  date_added  \
# 3837   s3838  TV SHOW  Jailbirds  Unknown  Unknown  Unknown  05/10/2019
#
#       release_year rating  duration               listed_in  \
# 3837          2019  tv-ma  1 Season  Docuseries, Reality TV
#
#                                             description
# 3837  At the Sacramento County Jail, incarcerated wo...

# %%
df.drop_duplicates().head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  tv show          Blood & Water          Unknown
# 2      s3  tv show              Ganglands  Julien Leclercq
# 3      s4  TV SHOW  Jailbirds New Orleans          Unknown
# 4      s5  tv show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                            Unknown  united states
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   south africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                            Unknown        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          india
#
#            date_added  release_year rating   duration  \
# 0          25-09-2021          2020  pg-13     90 min
# 1  September 24, 2021          2021  tv-ma  2 Seasons
# ...

# %%
df = df.rename(columns={"date_added": "data_year"})
df.tail()
# Out:
#      show_id     type                title  \
# 8978    s260    movie               Pahuna
# 8979   s2989    movie              Menashe
# 8980   s4237    MOVIE  Mexicanos de Bronce
# 8981    s578  TV SHOW      Masameer County
# 8982   s2399    movie           Okko's Inn
#
#                                     director  \
# 8978                                 Unknown
# 8979  Josh Z. Weinstein, Joshua Z. Weinstein
# 8980                                 Unknown
# 8981                             Malik Nejer
# 8982                           Kitaro Kosaka
#
#                                                    cast        country  \
# 8978                                            Unknown        Unknown
# 8979  Menashe Lustig, Ruben Niborski, Yoel Weisshaus...  united states
# 8980                                            Unknown        Unknown
# 8981  Malik Nejer, Abdulaziz Alshehri, Mazroa Almazr...        Unknown
# ...

# %%
df['country'] = df['country'].str.strip()
df['country']
# Out:
# 0       united states
# 1        south africa
# 2             Unknown
# 3             Unknown
# 4               india
#             ...
# 8978          Unknown
# 8979    united states
# 8980          Unknown
# 8981          Unknown
# 8982            japan
# Name: country, Length: 8983, dtype: object

# %%
df['title']
# Out:
# 0        Dick Johnson Is Dead
# 1               Blood & Water
# 2                   Ganglands
# 3       Jailbirds New Orleans
# 4                Kota Factory
#                 ...
# 8978                   Pahuna
# 8979                  Menashe
# 8980      Mexicanos de Bronce
# 8981          Masameer County
# 8982               Okko's Inn
# Name: title, Length: 8983, dtype: object

# %%
df[['title', 'release_year']].head(10)
# Out:
#                               title  release_year
# 0              Dick Johnson Is Dead          2020
# 1                     Blood & Water          2021
# 2                         Ganglands          2021
# 3             Jailbirds New Orleans          2021
# 4                      Kota Factory          2021
# 5                     Midnight Mass          2021
# 6  My Little Pony: A New Generation          2021
# 7                           Sankofa          1993
# 8     The Great British Baking Show          2021
# 9                      The Starling          2021

# %%
 df['director'].fillna(df['rating'])
# Out:
# 0                              Kirsten Johnson
# 1                                      Unknown
# 2                              Julien Leclercq
# 3                                      Unknown
# 4                                      Unknown
#                          ...
# 8978                                   Unknown
# 8979    Josh Z. Weinstein, Joshua Z. Weinstein
# 8980                                   Unknown
# 8981                               Malik Nejer
# 8982                             Kitaro Kosaka
# Name: director, Length: 8983, dtype: object

# %%
df.drop_duplicates(inplace=True)
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  tv show          Blood & Water          Unknown
# 2      s3  tv show              Ganglands  Julien Leclercq
# 3      s4  TV SHOW  Jailbirds New Orleans          Unknown
# 4      s5  tv show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                            Unknown  united states
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   south africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                            Unknown        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          india
#
#             data_year  release_year rating   duration  \
# 0          25-09-2021          2020  pg-13     90 min
# 1  September 24, 2021          2021  tv-ma  2 Seasons
# ...

# %%
df['country'].str.lower().str.strip()
# Out:
# 0       united states
# 1        south africa
# 2             unknown
# 3             unknown
# 4               india
#             ...
# 8978          unknown
# 8979    united states
# 8980          unknown
# 8981          unknown
# 8982            japan
# Name: country, Length: 8956, dtype: object

# %%
df['cast'] = df['cast'].fillna("Unknown")
df['cast']
# Out:
# 0                                                 Unknown
# 1       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                 Unknown
# 4       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
#                               ...
# 8978                                              Unknown
# 8979    Menashe Lustig, Ruben Niborski, Yoel Weisshaus...
# 8980                                              Unknown
# 8981    Malik Nejer, Abdulaziz Alshehri, Mazroa Almazr...
# 8982    Seiran Kobayashi, Nana Mizuki, Satsumi Matsuda...
# Name: cast, Length: 8956, dtype: object

# %%
df['rating'] = df['rating'].fillna("Not Rated")
df['rating']
# Out:
# 0       pg-13
# 1       tv-ma
# 2       tv-ma
# 3       tv-ma
# 4       tv-ma
#         ...
# 8978    tv-pg
# 8979       pg
# 8980    tv-ma
# 8981    tv-ma
# 8982       pg
# Name: rating, Length: 8956, dtype: object

# %%
df.columns = df.columns.str.strip().str.upper().str.replace(' ', '_')
df.columns
# Out:
# Index(['SHOW_ID', 'TYPE', 'TITLE', 'DIRECTOR', 'CAST', 'COUNTRY', 'DATA_YEAR',
#        'RELEASE_YEAR', 'RATING', 'DURATION', 'LISTED_IN', 'DESCRIPTION'],
#       dtype='object')

# %%
df.to_csv("netflix_titles_sample.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 df.to_csv("netflix_titles_sample.csv", index=False)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
